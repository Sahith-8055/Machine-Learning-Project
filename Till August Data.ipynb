# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('till_aug_data.csv')

# %%
data.head()
# Out:
#    Unnamed: 0   image   acct_no  cont_no  line_no              newacct_no  \
# 0      479167  201908  91044230        1       39  91044230.001.000000039
# 1      479168  201908  70057005        1       42  70057005.001.000000042
# 2      479169  201908  70057005        1       47  70057005.001.000000047
# 3      479170  201908  70057005        1       48  70057005.001.000000048
# 4      479171  201908  70066857        1       61  70066857.001.000000061
#
#   line_stat  bill_cycl serv_type   serv_code          district  tenure  \
# 0        AC          1       BBS        PB15          TSING YI      26
# 1        AC          1       BBS  VP2M2MFS1X          TSING YI     225
# 2        AC          1       BBS  VP2M2MFS1X          TSING YI     225
# 3        AC          1       BBS  VP2M2MFS1X          TSING YI     225
# 4        AC          1       BBS   PF1000F6R  CENTRAL DISTRICT     225
#
#    contract_month  secured_revenue     bandwidth  complaint_cnt churn  \
# ...

# %%
data.describe()
# Out:
#           Unnamed: 0          image       acct_no       cont_no       line_no  \
# count   34837.000000   34837.000000  3.483700e+04  34837.000000  34837.000000
# mean   465914.921606  201895.112754  8.936980e+07      2.548784  68689.635589
# std    114083.702113      33.172865  8.676535e+06      8.217767  23911.481924
# min        28.000000  201801.000000  7.004513e+07      1.000000     39.000000
# 25%    482635.000000  201908.000000  9.024698e+07      1.000000  60640.000000
# 50%    491344.000000  201908.000000  9.406993e+07      1.000000  76396.000000
# 75%    500053.000000  201908.000000  9.496843e+07      1.000000  85990.000000
# max    615886.000000  201908.000000  9.638900e+07    123.000000  95796.000000
#
#        bill_cycl        tenure  contract_month  secured_revenue  complaint_cnt
# count    34837.0  34837.000000    34837.000000     34837.000000   34837.000000
# mean         1.0     63.908459       21.308810      1856.601056       0.022821
# ...

# %%
df = data.copy()
df.head(5)
# Out:
#    Unnamed: 0   image   acct_no  cont_no  line_no              newacct_no  \
# 0      479167  201908  91044230        1       39  91044230.001.000000039
# 1      479168  201908  70057005        1       42  70057005.001.000000042
# 2      479169  201908  70057005        1       47  70057005.001.000000047
# 3      479170  201908  70057005        1       48  70057005.001.000000048
# 4      479171  201908  70066857        1       61  70066857.001.000000061
#
#   line_stat  bill_cycl serv_type   serv_code          district  tenure  \
# 0        AC          1       BBS        PB15          TSING YI      26
# 1        AC          1       BBS  VP2M2MFS1X          TSING YI     225
# 2        AC          1       BBS  VP2M2MFS1X          TSING YI     225
# 3        AC          1       BBS  VP2M2MFS1X          TSING YI     225
# 4        AC          1       BBS   PF1000F6R  CENTRAL DISTRICT     225
#
#    contract_month  secured_revenue     bandwidth  complaint_cnt churn  \
# ...

# %%
df = df.rename(columns={'Unnamed: 0':'Unnamed'})
# df = df.drop(['Unnamed', 'image'], axis=1
df.head(5)
# Out:
#    Unnamed   image   acct_no  cont_no  line_no              newacct_no  \
# 0   479167  201908  91044230        1       39  91044230.001.000000039
# 1   479168  201908  70057005        1       42  70057005.001.000000042
# 2   479169  201908  70057005        1       47  70057005.001.000000047
# 3   479170  201908  70057005        1       48  70057005.001.000000048
# 4   479171  201908  70066857        1       61  70066857.001.000000061
#
#   line_stat  bill_cycl serv_type   serv_code          district  tenure  \
# 0        AC          1       BBS        PB15          TSING YI      26
# 1        AC          1       BBS  VP2M2MFS1X          TSING YI     225
# 2        AC          1       BBS  VP2M2MFS1X          TSING YI     225
# 3        AC          1       BBS  VP2M2MFS1X          TSING YI     225
# 4        AC          1       BBS   PF1000F6R  CENTRAL DISTRICT     225
#
#    contract_month  secured_revenue     bandwidth  complaint_cnt churn  \
# ...

# %%
df = df.drop(['Unnamed', 'acct_no', 'cont_no', 'line_no', 'churn', 'serv_code', 'serv_type', 'bill_cycl', 'line_stat', 'image', 'newacct_no'], axis='columns')
df.head(5)
# Out:
#            district  tenure  contract_month  secured_revenue     bandwidth  \
# 0          TSING YI      26             0.0             1288     BELOW 10M
# 1          TSING YI     225             0.0              638     BELOW 10M
# 2          TSING YI     225             0.0              638     BELOW 10M
# 3          TSING YI     225             0.0              638     BELOW 10M
# 4  CENTRAL DISTRICT     225            12.0            15999  1000M (FTTO)
#
#    complaint_cnt current_mth_churn
# 0              0                 N
# 1              0                 N
# 2              0                 N
# 3              0                 N
# 4              0                 N

# %%
df.shape
# Out:
# (34837, 7)

# %%
df.describe()
# Out:
#              tenure  contract_month  secured_revenue  complaint_cnt
# count  34837.000000    34837.000000     34837.000000   34837.000000
# mean      63.908459       21.308810      1856.601056       0.022821
# std       50.153869       11.079326      2348.400953       0.191151
# min        4.000000        0.000000         0.000000       0.000000
# 25%       26.000000       24.000000       898.000000       0.000000
# 50%       47.000000       24.000000       898.000000       0.000000
# 75%       92.000000       24.000000      2850.000000       0.000000
# max      226.000000      120.000000     90000.000000       7.000000

# %%
df.iloc[2]
# Out:
# district              TSING YI
# tenure                     225
# contract_month               0
# secured_revenue            638
# bandwidth            BELOW 10M
# complaint_cnt                0
# current_mth_churn            N
# Name: 2, dtype: object

# %%
df.loc[2:4]
# Out:
#            district  tenure  contract_month  secured_revenue     bandwidth  \
# 2          TSING YI     225             0.0              638     BELOW 10M
# 3          TSING YI     225             0.0              638     BELOW 10M
# 4  CENTRAL DISTRICT     225            12.0            15999  1000M (FTTO)
#
#    complaint_cnt current_mth_churn
# 2              0                 N
# 3              0                 N
# 4              0                 N

# %%
X = df.values[:, :-1]
y = df.values[:, -1]

print(X.shape)
print(y.shape)
# Out:
# (34837, 6)
# (34837,)

# %%
df.isnull().sum()
# Out:
# district             0
# tenure               0
# contract_month       0
# secured_revenue      0
# bandwidth            0
# complaint_cnt        0
# current_mth_churn    0
# dtype: int64

# %%
df = df.rename(columns={'current_mth_churn':'Churn'})
df.head(5)
# Out:
#            district  tenure  contract_month  secured_revenue     bandwidth  \
# 0          TSING YI      26             0.0             1288     BELOW 10M
# 1          TSING YI     225             0.0              638     BELOW 10M
# 2          TSING YI     225             0.0              638     BELOW 10M
# 3          TSING YI     225             0.0              638     BELOW 10M
# 4  CENTRAL DISTRICT     225            12.0            15999  1000M (FTTO)
#
#    complaint_cnt Churn
# 0              0     N
# 1              0     N
# 2              0     N
# 3              0     N
# 4              0     N

# %%
df.Churn.value_counts()
# Out:
# N    26101
# Y     8736
# Name: Churn, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")
ax = sns.barplot(x="Churn", y="tenure", data=df)
# Out:
# c:\users\y.sahith\appdata\local\programs\python\python37\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
a = sns.barplot(x="Churn", y="tenure", hue="bandwidth", data=df)
# Out:
# c:\users\y.sahith\appdata\local\programs\python\python37\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
pair = sns.pairplot(df[['tenure', 'contract_month', 'secured_revenue', 'complaint_cnt', 'Churn']], hue="Churn", palette="husl", plot_kws=dict(alpha=0.3, edgecolor='none'), height=2, aspect=1.1)
# Out:
# c:\users\y.sahith\appdata\local\programs\python\python37\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.set(rc={'figure.figsize':(8,6)})
sns.heatmap(df[['tenure', 'contract_month', 'secured_revenue', 'complaint_cnt']].corr(), cmap='seismic', annot=True, vmin=-1, vmax=1)
