# %%
# Insert code here.
# !pip install tweepy
# Out:
# ...
#      |████████████████████████████████| 153kB 9.1MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 19.3.1; however, version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import tweepy
consumer_key = 'K9rMNMpPcNuCBQDTBzTZNeATQ'
consumer_secret = 'cI8srQZkCkAfaMjhnHrvrjvbjh8Nitk6pFQBbqBw1QNkJMuZOR'
access_token = '848495351543635968-5nn16G8TTe4wPzh1t3RM9ydoDdepXTO'
access_token_secret = 'oeYGcb3Z9g9sEVnlLUp9lRlZlyD6jHIrbMjnsYL0jGqZx'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
public_tweets = api.home_timeline()
for tweets in public_tweets:
    print(tweets.text)
    print('------------')
    print(tweets.created_at)
# Out:
# There is an acute shortage of PPEs for medical professionals in the country who are treating coronavirus patients.
#
# https://t.co/DzhR6w015r
# ------------
# 2020-04-05 16:17:27
# #9pm9minute – PM Narendra Modi lights up Diyas leading the nation in the fight against coronavirus.
#
# #LightForIndia… https://t.co/3CSXqyKjvd
# ------------
# 2020-04-05 16:17:26
# A prayer will always help. 🙏 https://t.co/ejeEnzbVME
# ------------
# 2020-04-05 16:17:25
# New York reports nearly 600 new deaths from coronavirus in 24 hours. Latest updates: https://t.co/bGVGTUS7CV https://t.co/etV1FhiUeF
# ------------
# 2020-04-05 16:17:24
# Diyas 🪔 all around.
# Such a delightful scenes to watch.
# This is what we can witness if all come together for a cause… https://t.co/ovCCa9krGY
# ------------
# 2020-04-05 16:17:16
# #SaiKumar and his wife Took part in #LightForIndia #9pm9minutes #StayHomeStaySafe
# #IndiaFightsCoronavirus https://t.co/GJIc32r29U
# ------------
# 2020-04-05 16:17:15
# ...

# %%
name = "nytimes"
tweetCount = 20
results = api.user_timeline(id=name, count=tweetCount)
for tweet in results:
    print(tweet.text)
# Out:
# For now, keeping the lockdown in place — even for longer than is strictly necessary — is the safest way for Italy t… https://t.co/2ARhhbjnBP
# Breaking News: A Navy captain who was removed from command of a coronavirus-stricken aircraft carrier tested positi… https://t.co/aSL4X0gwhZ
# Italy's lockdown was scheduled to lift on April 3 but officials extended it because the country was still reporting… https://t.co/1mPphZOykA
# Lombardy, the Italian region where the coronavirus outbreak was first detected, has been hit hardest.
#
# But Lombardy… https://t.co/ySbTkkUx00
# Now a month into the nationwide lockdown, the number of new coronavirus cases in Italy seems to be decreasing. But… https://t.co/uAJZdI20AI
# These extreme measures appear to have worked: Most people stopped moving around.
#
# Researchers found sharp reductio… https://t.co/iJkolwKyVD
# But the March 8 order leaked early, and many people fled the area before it took effect.
#
# ...

# %%
query = "coronavirus"
language = "en"

results = api.search(q=query, lang=language)
for tweet in results:
    print(tweet.text)
# Out:
# RT @SydneyBaliii: Due to #COVID19 aka #Coronavirus Ill be sending the first 500 people to like &amp; retweet this $300 -$1500 through CashApp ,…
# RT @CDCgov: #DYK? CDC’s recommendation on wearing a cloth face covering may help protect the most vulnerable from #COVID19. Watch @Surgeon_…
# Nostradamus 2020: Viral meme claims Nostradamus predicted coronavirus - but did he? https://t.co/FXEsTW6Hkc
# RT @ScottAdamsSays: Trump is not “touting” a #coronavirus drug. He is making a risk-reward observation that is 100% consistent with the opi…
# Just days ago, Comcast said: "First and foremost, it’s important to know that the network is performing well. Custo… https://t.co/Qnag5wvKeC
# RT @BorisJohnson: Thank you to everyone who is saving lives by staying at home this weekend.
#
# I know it's tough, but if we all work togeth…
# RT @tribelaw: One disgraceful reason Trump may not be too eager to get more people tested:
#
# More universal testing would help cope with CO…
# ...
